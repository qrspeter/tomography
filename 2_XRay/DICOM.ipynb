# %% [markdown]
# # DICOM data
#
# Group No

# %%
import pydicom as dicom

path = "./1.dcm"
x = dicom.dcmread(path)
print(x)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.9.2.6.1.192.168.244.59.16838.20180905102143.531
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.5.4
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_354'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: ['ISO 2022 IR 6', 'IS']
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0012) Instance Creation Date              DA: ''
# (0008, 0013) Instance Creation Time              TM: ''
# ...

# %%
import matplotlib.pyplot as plt

plt.imshow(x.pixel_array)
plt.show()

plt.imshow(x.pixel_array,cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# ## Plotly visualization of DICOM images
#
# (a bit outdated example - "we use Python 3.6 and pydicom 1.0.2", Python 3.6 was released in 2016)
#
# https://notebook.community/empet/Plotly-plots/DICOM-Image-viz.ipynb
#
#
# Plotly - интерактивный вариант matplotlib.
